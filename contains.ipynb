# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from shapely.geometry import Point, Polygon
import folium
from shapely.geometry import LineString
from sympy import centroid
from geopandas import GeoDataFrame
from math import nan

# %% [markdown]
# ### Adding Tweet Locations
# Outputs for maps and plots have been commented out due to github size constraints

# %%
tweets = pd.read_csv('SA_Tweets_All_Locations_v2.csv')

# %%
tweets.head(3)
# Out:
#    Unnamed: 0            author_id         username  author_followers  \
# 0           0  1353804645580353537      ranthotse17              1433
# 1           1  1258457287120818182  Michael86259668              1323
# 2           2           2496356957         KabeloMG              1436
#
#    author_tweets                                 author_description  \
# 0           2648                                        all is well
# 1          29766  plus500 associate commodity fx and cfd trader ...
# 2          35414  This is Twitter.We tweet like birds hence the ...
#
#   author_location                                               text  \
# 0        Limpopo   Go shota R1000 ya registration \n\nBlesser: +R...
# 1    South Africa  Spx yesterday's rally\nPoof gone https://t.co/...
# 2             NaN  @JohnPerlman A driverless car wouldn't work in...
#
#                   created_at  retweets  replies  likes  quote_count  \
# 0  2022-09-29 19:40:06+00:00         0        0      1            0
# 1  2022-09-29 14:17:35+00:00         0        0      1            0
# 2  2022-09-29 13:49:14+00:00         1        0      0            0
#
#                            place_id              place_name  \
# 0  {'place_id': 'dd9c0d7d7e07eb49'}            South Africa
# 1  {'place_id': 'a02e6c261fa62b42'}    Benoni, South Africa
# 2  {'place_id': '0e587c59401d0a27'}  Pretoria, South Africa
#
#                                                 bbox
# 0  [16.4475932, -34.8342468, 32.8922934, -22.1247...
# 1  [28.2722463, -26.2315204, 28.4449594, -26.0681...
# 2  [27.9483035, -25.9157727, 28.4198285, -25.5894...

# %%
tweets.shape
# Out:
# (21655, 16)

# %%
def bbox_to_coords(bbox):
    all_coords = bbox.split()
    coords = []
    for coordinate in all_coords:
        coordinate = coordinate.replace('[','')
        coordinate = coordinate.replace(']','')
        coordinate = coordinate.replace(',','')
        coord = float(coordinate)
        coords.append(coord)

    return coords

# %%
tweets['coords'] = tweets['bbox'].apply(lambda x: bbox_to_coords(x))

# %%
tweets['longitude_1'] = tweets['coords'].apply(lambda x: x[0])
tweets['latitude_1'] = tweets['coords'].apply(lambda x: x[1])
tweets['longitude_2'] = tweets['coords'].apply(lambda x: x[2])
tweets['latitude_2'] = tweets['coords'].apply(lambda x: x[3])

# %%
tweets.head(3)
# Out:
#    Unnamed: 0            author_id         username  author_followers  \
# 0           0  1353804645580353537      ranthotse17              1433
# 1           1  1258457287120818182  Michael86259668              1323
# 2           2           2496356957         KabeloMG              1436
#
#    author_tweets                                 author_description  \
# 0           2648                                        all is well
# 1          29766  plus500 associate commodity fx and cfd trader ...
# 2          35414  This is Twitter.We tweet like birds hence the ...
#
#   author_location                                               text  \
# 0        Limpopo   Go shota R1000 ya registration \n\nBlesser: +R...
# 1    South Africa  Spx yesterday's rally\nPoof gone https://t.co/...
# 2             NaN  @JohnPerlman A driverless car wouldn't work in...
#
#                   created_at  retweets  ...  likes  quote_count  \
# 0  2022-09-29 19:40:06+00:00         0  ...      1            0
# 1  2022-09-29 14:17:35+00:00         0  ...      1            0
# 2  2022-09-29 13:49:14+00:00         1  ...      0            0
#
#                            place_id              place_name  \
# 0  {'place_id': 'dd9c0d7d7e07eb49'}            South Africa
# 1  {'place_id': 'a02e6c261fa62b42'}    Benoni, South Africa
# 2  {'place_id': '0e587c59401d0a27'}  Pretoria, South Africa
#
#                                                 bbox  \
# 0  [16.4475932, -34.8342468, 32.8922934, -22.1247...
# 1  [28.2722463, -26.2315204, 28.4449594, -26.0681...
# 2  [27.9483035, -25.9157727, 28.4198285, -25.5894...
#
#                                               coords longitude_1  latitude_1  \
# 0  [16.4475932, -34.8342468, 32.8922934, -22.1247...   16.447593  -34.834247
# 1  [28.2722463, -26.2315204, 28.4449594, -26.0681...   28.272246  -26.231520
# 2  [27.9483035, -25.9157727, 28.4198285, -25.5894...   27.948304  -25.915773
#
#    longitude_2  latitude_2
# 0    32.892293  -22.124724
# 1    28.444959  -26.068193
# 2    28.419829  -25.589438
#
# [3 rows x 21 columns]

# %%
tweets = tweets.drop('bbox', axis=1)
tweets.head(3)
# Out:
#    Unnamed: 0            author_id         username  author_followers  \
# 0           0  1353804645580353537      ranthotse17              1433
# 1           1  1258457287120818182  Michael86259668              1323
# 2           2           2496356957         KabeloMG              1436
#
#    author_tweets                                 author_description  \
# 0           2648                                        all is well
# 1          29766  plus500 associate commodity fx and cfd trader ...
# 2          35414  This is Twitter.We tweet like birds hence the ...
#
#   author_location                                               text  \
# 0        Limpopo   Go shota R1000 ya registration \n\nBlesser: +R...
# 1    South Africa  Spx yesterday's rally\nPoof gone https://t.co/...
# 2             NaN  @JohnPerlman A driverless car wouldn't work in...
#
#                   created_at  retweets  replies  likes  quote_count  \
# 0  2022-09-29 19:40:06+00:00         0        0      1            0
# 1  2022-09-29 14:17:35+00:00         0        0      1            0
# 2  2022-09-29 13:49:14+00:00         1        0      0            0
#
#                            place_id              place_name  \
# 0  {'place_id': 'dd9c0d7d7e07eb49'}            South Africa
# 1  {'place_id': 'a02e6c261fa62b42'}    Benoni, South Africa
# 2  {'place_id': '0e587c59401d0a27'}  Pretoria, South Africa
#
#                                               coords  longitude_1  latitude_1  \
# 0  [16.4475932, -34.8342468, 32.8922934, -22.1247...    16.447593  -34.834247
# 1  [28.2722463, -26.2315204, 28.4449594, -26.0681...    28.272246  -26.231520
# 2  [27.9483035, -25.9157727, 28.4198285, -25.5894...    27.948304  -25.915773
#
#    longitude_2  latitude_2
# 0    32.892293  -22.124724
# 1    28.444959  -26.068193
# 2    28.419829  -25.589438

# %% [markdown]
# ### Centroid

# %%
def find_centroid(coords):
    geometry = LineString([(coords[0], coords[1]),(coords[2], coords[3])])
    centroid = geometry.centroid
    return centroid

# %%
tweets['centroid'] = tweets['coords'].apply(lambda x: find_centroid(x))

# %%
# tweets = tweets.drop('geometry', axis=1)
# tweets.head()

# %%
tweets['centroid_long'] = tweets['centroid'].apply(lambda z: z.x)
tweets['centroid_lat'] = tweets['centroid'].apply(lambda z: z.y)

# %%
tweets = tweets.drop('centroid', axis =1)
tweets.head()
# Out:
#    Unnamed: 0            author_id         username  author_followers  \
# 0           0  1353804645580353537      ranthotse17              1433
# 1           1  1258457287120818182  Michael86259668              1323
# 2           2           2496356957         KabeloMG              1436
# 3           3  1309123451433746437    TheLegitIcon2              6458
# 4           4            177685467        Nwabisa_1              1878
#
#    author_tweets                                 author_description  \
# 0           2648                                        all is well
# 1          29766  plus500 associate commodity fx and cfd trader ...
# 2          35414  This is Twitter.We tweet like birds hence the ...
# 3          37979  Phumlani, 𝒍𝒐𝒗𝒆𝒓, 𝒇𝒖𝒕𝒖𝒓𝒆 𝒍𝒆𝒂𝒅𝒆𝒓 𝒂𝒏𝒅 𝒂 𝒈𝒐𝒐𝒅 𝒄𝒉𝒂𝒓...
# 4          52381  mamCirha, Qhanqolo, Ncibane , Nojawolo, Ntswen...
#
#                   author_location  \
# 0                        Limpopo
# 1                    South Africa
# 2                             NaN
# 3  Pietermaritzburg, South Africa
# 4                          Joburg
#
#                                                 text  \
# 0  Go shota R1000 ya registration \n\nBlesser: +R...
# 1  Spx yesterday's rally\nPoof gone https://t.co/...
# 2  @JohnPerlman A driverless car wouldn't work in...
# 3  At least offer ukumbhalela ama board for that ...
# 4  We used to catch a train from Ikwezi to Mzimhl...
#
#                   created_at  retweets  ...  quote_count  \
# 0  2022-09-29 19:40:06+00:00         0  ...            0
# 1  2022-09-29 14:17:35+00:00         0  ...            0
# 2  2022-09-29 13:49:14+00:00         1  ...            0
# 3  2022-09-29 11:10:06+00:00         0  ...            0
# 4  2022-09-29 10:52:13+00:00         1  ...            0
#
#                            place_id                      place_name  \
# 0  {'place_id': 'dd9c0d7d7e07eb49'}                    South Africa
# 1  {'place_id': 'a02e6c261fa62b42'}            Benoni, South Africa
# 2  {'place_id': '0e587c59401d0a27'}          Pretoria, South Africa
# 3  {'place_id': '52e073e7724385c3'}  Pietermaritzburg, South Africa
# 4  {'place_id': '3e46a98adcf05e59'}       Meadowlands, South Africa
#
#                                               coords longitude_1 latitude_1  \
# 0  [16.4475932, -34.8342468, 32.8922934, -22.1247...   16.447593 -34.834247
# 1  [28.2722463, -26.2315204, 28.4449594, -26.0681...   28.272246 -26.231520
# 2  [27.9483035, -25.9157727, 28.4198285, -25.5894...   27.948304 -25.915773
# 3  [30.2563496, -29.6999989, 30.4512134, -29.5328...   30.256350 -29.699999
# 4  [27.8651453, -26.2359005, 27.9219768, -26.1964...   27.865145 -26.235900
#
#    longitude_2  latitude_2  centroid_long  centroid_lat
# 0    32.892293  -22.124724      24.669943    -28.479485
# 1    28.444959  -26.068193      28.358603    -26.149857
# 2    28.419829  -25.589438      28.184066    -25.752605
# 3    30.451213  -29.532801      30.353782    -29.616400
# 4    27.921977  -26.196478      27.893561    -26.216189
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Find Author Locations for place_name = South Africa

# %%
# from geopy.geocoders import Nominatim

# # Change to function so lambda expression can be used:
# def get_author_location(author_location):
#     loc = Nominatim(user_agent="GetLoc")
#     getLoc = loc.geocode(author_location, timeout=2)
#     if getLoc is not None:
#         return getLoc
#     else:
#         return nan

# %%
# count = 0
# authour_locs = []

# for index, tweet in tweets.iterrows():
#     loc = nan
#     if(tweet['place_name'] == 'South Africa'):
#         if(tweet['author_location'] != nan):
#             loc = get_author_location(tweet['author_location'])
#             if(loc == 'South Africa'):
#                 loc = nan
#         count = count + 1
#         print(count)
#     authour_locs.append(loc)


# tweets['actual_author_location'] = authour_locs

# %% [markdown]
# ### Fix Edge Cases
# Such as Cape Town

# %%
tweets.loc[tweets.place_name == 'Cape Town, South Africa', ['centroid_long', 'centroid_lat']] = 18.4241, -33.9249

# %% [markdown]
# ### Try plot on map

# %%
geometry = [Point(xy) for xy in zip(tweets['centroid_long'], tweets['centroid_lat'])]
gdf = GeoDataFrame(tweets, geometry=geometry)   

#this is a simple map that goes with geopandas
#world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);

# %%
gdf.head(2)
# Out:
#    Unnamed: 0            author_id         username  author_followers  \
# 0           0  1353804645580353537      ranthotse17              1433
# 1           1  1258457287120818182  Michael86259668              1323
#
#    author_tweets                                 author_description  \
# 0           2648                                        all is well
# 1          29766  plus500 associate commodity fx and cfd trader ...
#
#   author_location                                               text  \
# 0        Limpopo   Go shota R1000 ya registration \n\nBlesser: +R...
# 1    South Africa  Spx yesterday's rally\nPoof gone https://t.co/...
#
#                   created_at  retweets  ...                          place_id  \
# 0  2022-09-29 19:40:06+00:00         0  ...  {'place_id': 'dd9c0d7d7e07eb49'}
# 1  2022-09-29 14:17:35+00:00         0  ...  {'place_id': 'a02e6c261fa62b42'}
#
#              place_name                                             coords  \
# 0          South Africa  [16.4475932, -34.8342468, 32.8922934, -22.1247...
# 1  Benoni, South Africa  [28.2722463, -26.2315204, 28.4449594, -26.0681...
#
#   longitude_1 latitude_1 longitude_2  latitude_2  centroid_long  centroid_lat  \
# 0   16.447593 -34.834247   32.892293  -22.124724      24.669943    -28.479485
# 1   28.272246 -26.231520   28.444959  -26.068193      28.358603    -26.149857
#
#                      geometry
# 0  POINT (24.66994 -28.47949)
# 1  POINT (28.35860 -26.14986)
#
# [2 rows x 23 columns]

# %%
map = folium.Map(location = [-29, 27], tiles='OpenStreetMap' , zoom_start = 5.3)

# %%
#gdf.explore(m = map)

# %%
tweets = tweets.drop('longitude_1', axis=1)
tweets = tweets.drop('longitude_2', axis=1)
tweets = tweets.drop('latitude_1', axis=1)
tweets = tweets.drop('latitude_2', axis=1)
tweets = tweets.drop('centroid_long', axis=1)
tweets = tweets.drop('centroid_lat', axis=1)
tweets.head(2)
# Out:
#    Unnamed: 0            author_id         username  author_followers  \
# 0           0  1353804645580353537      ranthotse17              1433
# 1           1  1258457287120818182  Michael86259668              1323
#
#    author_tweets                                 author_description  \
# 0           2648                                        all is well
# 1          29766  plus500 associate commodity fx and cfd trader ...
#
#   author_location                                               text  \
# 0        Limpopo   Go shota R1000 ya registration \n\nBlesser: +R...
# 1    South Africa  Spx yesterday's rally\nPoof gone https://t.co/...
#
#                   created_at  retweets  replies  likes  quote_count  \
# 0  2022-09-29 19:40:06+00:00         0        0      1            0
# 1  2022-09-29 14:17:35+00:00         0        0      1            0
#
#                            place_id            place_name  \
# 0  {'place_id': 'dd9c0d7d7e07eb49'}          South Africa
# 1  {'place_id': 'a02e6c261fa62b42'}  Benoni, South Africa
#
#                                               coords  \
# 0  [16.4475932, -34.8342468, 32.8922934, -22.1247...
# 1  [28.2722463, -26.2315204, 28.4449594, -26.0681...
#
#                      geometry
# 0  POINT (24.66994 -28.47949)
# 1  POINT (28.35860 -26.14986)

# %% [markdown]
# ### Tweet Aggregates For Every Location

# %%
tweet_agg = tweets.groupby(['place_id']).size()
tweet_agg =pd.DataFrame({'place_id':tweet_agg.index, 'tweet_count':tweet_agg.values})
tweet_agg.head()
# Out:
#                                             place_id  tweet_count
# 0  {'coordinates': {'type': 'Point', 'coordinates...            1
# 1  {'coordinates': {'type': 'Point', 'coordinates...            1
# 2  {'coordinates': {'type': 'Point', 'coordinates...            1
# 3  {'coordinates': {'type': 'Point', 'coordinates...            1
# 4  {'coordinates': {'type': 'Point', 'coordinates...            8

# %%
def get_place_name(place_id):
    place_name_df = tweets.loc[tweets['place_id'] == place_id, 'place_name']
    place_name = place_name_df.unique()
    place_name = place_name[0]
    return place_name

# %%
from shapely.geometry import Point, mapping, shape
def get_place_geometry(place_id):
    place_geometry_df = tweets.loc[tweets['place_id'] == place_id, 'geometry']
    place_geometry = place_geometry_df.unique()
    place_geometry = place_geometry[0]
    return place_geometry

# %%
tweet_agg['place_name'] = tweet_agg['place_id'].apply(lambda x: get_place_name(x))
tweet_agg['place_coords'] = tweet_agg['place_id'].apply(lambda x: get_place_geometry(x))
tweet_agg.head()
# Out:
#                                             place_id  tweet_count  \
# 0  {'coordinates': {'type': 'Point', 'coordinates...            1
# 1  {'coordinates': {'type': 'Point', 'coordinates...            1
# 2  {'coordinates': {'type': 'Point', 'coordinates...            1
# 3  {'coordinates': {'type': 'Point', 'coordinates...            1
# 4  {'coordinates': {'type': 'Point', 'coordinates...            8
#
#                 place_name                      place_coords
# 0             South Africa    POINT (24.6699433 -28.4794852)
# 1  Noordhoek, South Africa  POINT (18.38045585 -34.10140905)
# 2  Cape Town, South Africa          POINT (18.4241 -33.9249)
# 3  Cape Town, South Africa          POINT (18.4241 -33.9249)
# 4  Cape Town, South Africa          POINT (18.4241 -33.9249)

# %%
tweet_agg = tweet_agg.set_index('place_id')
tweet_agg.head()
# Out:
#                                                     tweet_count  \
# place_id
# {'coordinates': {'type': 'Point', 'coordinates'...            1
# {'coordinates': {'type': 'Point', 'coordinates'...            1
# {'coordinates': {'type': 'Point', 'coordinates'...            1
# {'coordinates': {'type': 'Point', 'coordinates'...            1
# {'coordinates': {'type': 'Point', 'coordinates'...            8
#
#                                                                  place_name  \
# place_id
# {'coordinates': {'type': 'Point', 'coordinates'...             South Africa
# {'coordinates': {'type': 'Point', 'coordinates'...  Noordhoek, South Africa
# {'coordinates': {'type': 'Point', 'coordinates'...  Cape Town, South Africa
# {'coordinates': {'type': 'Point', 'coordinates'...  Cape Town, South Africa
# {'coordinates': {'type': 'Point', 'coordinates'...  Cape Town, South Africa
#
#                                                                         place_coords
# place_id
# {'coordinates': {'type': 'Point', 'coordinates'...    POINT (24.6699433 -28.4794852)
# {'coordinates': {'type': 'Point', 'coordinates'...  POINT (18.38045585 -34.10140905)
# {'coordinates': {'type': 'Point', 'coordinates'...          POINT (18.4241 -33.9249)
# {'coordinates': {'type': 'Point', 'coordinates'...          POINT (18.4241 -33.9249)
# {'coordinates': {'type': 'Point', 'coordinates'...          POINT (18.4241 -33.9249)

# %%
tweet_sums = tweets.groupby(['place_id'])[['retweets','quote_count', 'replies', 'likes', 'author_followers']].sum()
tweet_sums.head()
# Out:
#                                                     retweets  quote_count  \
# place_id
# {'coordinates': {'type': 'Point', 'coordinates'...         0            0
# {'coordinates': {'type': 'Point', 'coordinates'...         0            0
# {'coordinates': {'type': 'Point', 'coordinates'...         0            0
# {'coordinates': {'type': 'Point', 'coordinates'...         0            0
# {'coordinates': {'type': 'Point', 'coordinates'...         0            0
#
#                                                     replies  likes  \
# place_id
# {'coordinates': {'type': 'Point', 'coordinates'...        0      0
# {'coordinates': {'type': 'Point', 'coordinates'...        0      0
# {'coordinates': {'type': 'Point', 'coordinates'...        0      0
# {'coordinates': {'type': 'Point', 'coordinates'...        0      0
# {'coordinates': {'type': 'Point', 'coordinates'...        0      2
#
#                                                     author_followers
# place_id
# {'coordinates': {'type': 'Point', 'coordinates'...                14
# {'coordinates': {'type': 'Point', 'coordinates'...             11895
# {'coordinates': {'type': 'Point', 'coordinates'...              2072
# {'coordinates': {'type': 'Point', 'coordinates'...              1386
# {'coordinates': {'type': 'Point', 'coordinates'...              2720

# %%
tweet_agg = tweet_agg.join(tweet_sums)

# %%
tweet_agg['place_id'] = tweet_agg.index
tweet_agg = tweet_agg.reset_index(drop = True)
tweet_agg.head()
# Out:
#    tweet_count               place_name                      place_coords  \
# 0            1             South Africa    POINT (24.6699433 -28.4794852)
# 1            1  Noordhoek, South Africa  POINT (18.38045585 -34.10140905)
# 2            1  Cape Town, South Africa          POINT (18.4241 -33.9249)
# 3            1  Cape Town, South Africa          POINT (18.4241 -33.9249)
# 4            8  Cape Town, South Africa          POINT (18.4241 -33.9249)
#
#    retweets  quote_count  replies  likes  author_followers  \
# 0         0            0        0      0                14
# 1         0            0        0      0             11895
# 2         0            0        0      0              2072
# 3         0            0        0      0              1386
# 4         0            0        0      2              2720
#
#                                             place_id
# 0  {'coordinates': {'type': 'Point', 'coordinates...
# 1  {'coordinates': {'type': 'Point', 'coordinates...
# 2  {'coordinates': {'type': 'Point', 'coordinates...
# 3  {'coordinates': {'type': 'Point', 'coordinates...
# 4  {'coordinates': {'type': 'Point', 'coordinates...

# %%
tweet_agg_temp = tweet_agg
tweet_agg = tweet_agg.drop('place_coords', axis = 1)

gdf2 = GeoDataFrame(tweet_agg, geometry=tweet_agg_temp['place_coords']) 
gdf2.explore(m = map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83bc7f0d41b7d7b3f18f7e7b6e712a6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83bc7f0d41b7d7b3f18f7e7b6e712a6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_83bc7f0d41b7d7b3f18f7e7b6e712a6c = L.map(
#                 &quot;map_83bc7f0d41b7d7b3f18f7e7b6e712a6c&quot;,
#                 {
#                     center: [-29.0, 27.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c0319a477e61bb53738353d51f7a5a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83bc7f0d41b7d7b3f18f7e7b6e712a6c);
#
#
#         function geo_json_8a51c188c6690091efaa50f1a1b05e4a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8a51c188c6690091efaa50f1a1b05e4a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8a51c188c6690091efaa50f1a1b05e4a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8a51c188c6690091efaa50f1a1b05e4a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8a51c188c6690091efaa50f1a1b05e4a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8a51c188c6690091efaa50f1a1b05e4a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8a51c188c6690091efaa50f1a1b05e4a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8a51c188c6690091efaa50f1a1b05e4a = L.geoJson(null, {
#                 onEachFeature: geo_json_8a51c188c6690091efaa50f1a1b05e4a_onEachFeature,
#
#                 style: geo_json_8a51c188c6690091efaa50f1a1b05e4a_styler,
#                 pointToLayer: geo_json_8a51c188c6690091efaa50f1a1b05e4a_pointToLayer
#         });
#
#         function geo_json_8a51c188c6690091efaa50f1a1b05e4a_add (data) {
#             geo_json_8a51c188c6690091efaa50f1a1b05e4a
#                 .addData(data)
#                 .addTo(map_83bc7f0d41b7d7b3f18f7e7b6e712a6c);
#         }
#             geo_json_8a51c188c6690091efaa50f1a1b05e4a_add({&quot;bbox&quot;: [17.8906261, -34.53316395, 32.2722906, -22.344388000000002], &quot;features&quot;: [{&quot;bbox&quot;: [24.6699433, -28.4794852, 24.6699433, -28.4794852], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.6699433, -28.4794852], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;author_followers&quot;: 14, &quot;likes&quot;: 0, &quot;place_id&quot;: &quot;{\u0027coordinates\u0027: {\u0027type\u0027: \u0027Point\u0027, \u0027coordinates\u0027: [18.34921, -33.05852]}, \u0027place_id\u0027: \u0027dd9c0d7d7e07eb49\u0027}&quot;, &quot;place_name&quot;: &quot;South Africa&quot;, &quot;quote_count&quot;: 0, &quot;replies&quot;: 0, &quot;retweets&quot;: 0, &quot;tweet_count&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [18.38045585, -34.10140905, 18.38045585, -34.10140905], &quot;geometry&quot;: {&quot;coordinates&quot;: [18.38045585, -34.10140905], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;author_followers&quot;: 11895, &quot;li

# %%
tweet_agg.head()
# Out:
#    tweet_count               place_name  retweets  quote_count  replies  \
# 0            1             South Africa         0            0        0
# 1            1  Noordhoek, South Africa         0            0        0
# 2            1  Cape Town, South Africa         0            0        0
# 3            1  Cape Town, South Africa         0            0        0
# 4            8  Cape Town, South Africa         0            0        0
#
#    likes  author_followers                                           place_id  \
# 0      0                14  {'coordinates': {'type': 'Point', 'coordinates...
# 1      0             11895  {'coordinates': {'type': 'Point', 'coordinates...
# 2      0              2072  {'coordinates': {'type': 'Point', 'coordinates...
# 3      0              1386  {'coordinates': {'type': 'Point', 'coordinates...
# 4      2              2720  {'coordinates': {'type': 'Point', 'coordinates...
#
#                      geometry
# 0  POINT (24.66994 -28.47949)
# 1  POINT (18.38046 -34.10141)
# 2  POINT (18.42410 -33.92490)
# 3  POINT (18.42410 -33.92490)
# 4  POINT (18.42410 -33.92490)

# %%
tweet_agg.to_csv('Tweet_Locations.csv')

# %% [markdown]
# ### Things still to do
#
# Last thing to do is to put the tweets into each munuciplality/ province

# %%
tweets.head()
# Out:
#    Unnamed: 0            author_id         username  author_followers  \
# 0           0  1353804645580353537      ranthotse17              1433
# 1           1  1258457287120818182  Michael86259668              1323
# 2           2           2496356957         KabeloMG              1436
# 3           3  1309123451433746437    TheLegitIcon2              6458
# 4           4            177685467        Nwabisa_1              1878
#
#    author_tweets                                 author_description  \
# 0           2648                                        all is well
# 1          29766  plus500 associate commodity fx and cfd trader ...
# 2          35414  This is Twitter.We tweet like birds hence the ...
# 3          37979  Phumlani, 𝒍𝒐𝒗𝒆𝒓, 𝒇𝒖𝒕𝒖𝒓𝒆 𝒍𝒆𝒂𝒅𝒆𝒓 𝒂𝒏𝒅 𝒂 𝒈𝒐𝒐𝒅 𝒄𝒉𝒂𝒓...
# 4          52381  mamCirha, Qhanqolo, Ncibane , Nojawolo, Ntswen...
#
#                   author_location  \
# 0                        Limpopo
# 1                    South Africa
# 2                             NaN
# 3  Pietermaritzburg, South Africa
# 4                          Joburg
#
#                                                 text  \
# 0  Go shota R1000 ya registration \n\nBlesser: +R...
# 1  Spx yesterday's rally\nPoof gone https://t.co/...
# 2  @JohnPerlman A driverless car wouldn't work in...
# 3  At least offer ukumbhalela ama board for that ...
# 4  We used to catch a train from Ikwezi to Mzimhl...
#
#                   created_at  retweets  replies  likes  quote_count  \
# 0  2022-09-29 19:40:06+00:00         0        0      1            0
# 1  2022-09-29 14:17:35+00:00         0        0      1            0
# 2  2022-09-29 13:49:14+00:00         1        0      0            0
# 3  2022-09-29 11:10:06+00:00         0        0      1            0
# 4  2022-09-29 10:52:13+00:00         1        0      1            0
#
#                            place_id                      place_name  \
# 0  {'place_id': 'dd9c0d7d7e07eb49'}                    South Africa
# 1  {'place_id': 'a02e6c261fa62b42'}            Benoni, South Africa
# 2  {'place_id': '0e587c59401d0a27'}          Pretoria, South Africa
# 3  {'place_id': '52e073e7724385c3'}  Pietermaritzburg, South Africa
# 4  {'place_id': '3e46a98adcf05e59'}       Meadowlands, South Africa
#
#                                               coords  \
# 0  [16.4475932, -34.8342468, 32.8922934, -22.1247...
# 1  [28.2722463, -26.2315204, 28.4449594, -26.0681...
# 2  [27.9483035, -25.9157727, 28.4198285, -25.5894...
# 3  [30.2563496, -29.6999989, 30.4512134, -29.5328...
# 4  [27.8651453, -26.2359005, 27.9219768, -26.1964...
#
#                      geometry
# 0  POINT (24.66994 -28.47949)
# 1  POINT (28.35860 -26.14986)
# 2  POINT (28.18407 -25.75261)
# 3  POINT (30.35378 -29.61640)
# 4  POINT (27.89356 -26.21619)

# %%
tweets.to_csv('Full_Tweets.csv')
